# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns


# Load the Titanic dataset
titanic = sns.load_dataset("titanic")

# Create a countplot
count_plot = sns.countplot(x="class", data=titanic)

# Set the title and show the plot
plt.title("Passenger Class Distribution on the Titanic")

# plt.show()
maidr.show(count_plot)
# Out:
# <iframe srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;c7f4a8c6-a3f9-45e7-9464-b959e6865ced&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-08-18T10:23:50.290232&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.9.1.post1, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;patch_3&quot; maidr=&quot;true&quot;&gt;&#10;    &lt;path d=&quot;M 69.504 307.584  L 164.736 307.584  L 164.736 196.091047  L 69.504 196.091047  z &quot; clip-path=&quot;url(#pb502bc15f0)&quot; style=&quot;fill: #3274a1&quot; maidr=&quot;true&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;patch_4&quot; maidr=&quot;true&quot;&gt;&#10;    &lt;path d=&quot;M 188.544 307.584  L 283.776 307.584  L 283.776 212.608521  L 188.544 212.608521  z &quot; clip-path=&quot;url(#pb502bc15f0)&quot; style=&quot;fill: #3274a1&quot; maidr=&quot;true&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;patch_5&quot; maidr=&quot;true&quot;&gt;&#10;    &lt;path d=&quot;M 307.584 307.584  L 402.816 307.584  L 402.816 54.144  L 307.584 54.144  z &quot; clip-path=&quot;url(#pb502bc15f0)&quot; style=&quot;fill: #3274a1&quot; maidr=&quot;true&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;m2ebc1856bf&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#m2ebc1856bf&quot; x=&quot;117.12&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- First --&gt;&#10;      &lt;g transform=&quot;translate(106.597344 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-46&quot; d=&quot;M 628 4666  L 3309 4666  L 3309 4134  L 1259 4134  L 1259 2759  L 3109 2759  L 3109 2228  L 1259 2228  L 1259 0  L 628 0  L 628 4666  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-69&quot; d=&quot;M 603 3500  L 1178 3500  L 1178 0  L 603 0  L 603 350 ...
