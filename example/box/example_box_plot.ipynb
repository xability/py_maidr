# %%
# %matplotlib auto
# Out:
# Using matplotlib backend: macosx

# %%
import matplotlib.pyplot as plt
import maidr
import numpy as np

# Generating random data for three different groups
data_group1 = np.random.normal(100, 10, 200)
data_group2 = np.random.normal(90, 20, 200)
data_group3 = np.random.normal(80, 30, 200)

# Combine these different datasets into a list
data_to_plot = [data_group1, data_group2, data_group3]


# Create the boxplot
def boxplot(is_vert: bool):
    plt.figure()
    bp = plt.boxplot(data_to_plot, patch_artist=True, vert=is_vert)

    colors = ["lightblue", "lightgreen", "tan"]
    for patch, color in zip(bp["boxes"], colors):
        patch.set_facecolor(color)

    if is_vert:
        plt.xticks(ticks=[1, 2, 3], labels=["Group 1", "Group 2", "Group 3"])
        plt.title("Vertical Box Plot Example")
        plt.xlabel("Group")
        plt.ylabel("Values")
    else:
        plt.yticks(ticks=[1, 2, 3], labels=["Group 1", "Group 2", "Group 3"])
        plt.title("Horizontal Box Plot Example")
        plt.ylabel("Group")
        plt.xlabel("Values")

    return bp


# Create the vertical boxplot
vert = boxplot(is_vert=True)
# plt.show()
maidr.show(vert)
# Out:
# <iframe id="iframe_02f11f0a-064d-4a75-b0a5-964a52c93cef" srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;d34d4bfe-d9ef-4820-810c-a8cf6e6358e0&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-09-30T05:10:47.668761&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.9.2, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;ma54ba8cfc9&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#ma54ba8cfc9&quot; x=&quot;117.12&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- Group 1 --&gt;&#10;      &lt;g transform=&quot;translate(97.130156 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-47&quot; d=&quot;M 3809 666  L 3809 1919  L 2778 1919  L 2778 2438  L 4434 2438  L 4434 434  Q 4069 175 3628 42  Q 3188 -91 2688 -91  Q 1594 -91 976 548  Q 359 1188 359 2328  Q 359 3472 976 4111  Q 1594 4750 2688 4750  Q 3144 4750 3555 4637  Q 3966 4525 4313 4306  L 4313 3634  Q 3963 3931 3569 4081  Q 3175 4231 2741 4231  Q 1884 4231 1454 3753  Q 1025 3275 1025 2328  Q 1025 1384 1454 906  Q 1884 428 2741 428  Q 3075 428 3337 486  Q 3600 544 3809 666  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-72&quot; d=&quot;M 2631 2963  Q 2534 3019 2420 3045  Q 2306 3072 2169 3072  Q 1681 3072 1420 2755  Q 1159 2438 1159 1844  L 1159 0  L 581 0  L 581 3500  L 1159 3500  L 1159 2956  Q 1341 3275 1631 3429  Q 1922 3584 2338 3584  Q 2397 3584 2469 3576  Q 2541 3569 2628 3553  L 2631 2963  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-6f&quot; d=&quot;M 1959 3097  Q 1497 3097 1228 2736  Q 959 2375 959 1747  Q 959 1119 1226 758  Q 1494 397 1959 397  Q 2419 397 2687 759  Q 2956 1122 2956 1747  Q 2956 2369 2687 2733  Q 2419 3097 1959 3097  z M 1959 3584  Q 270 ...

# %%
# Create the vertical boxplot
horz = boxplot(is_vert=False)
# plt.show()
maidr.show(horz)
# Out:
# <iframe id="iframe_2eb9ca59-eed6-4547-986e-c7ca5344a500" srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;9aac6c5f-c7a0-4336-9e2c-1ce799dba6ea&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-09-30T05:10:55.781795&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.9.2, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;m9c9d0cf3b9&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#m9c9d0cf3b9&quot; x=&quot;99.621626&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- 0 --&gt;&#10;      &lt;g transform=&quot;translate(96.440376 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-30&quot; d=&quot;M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;       &lt;/defs&gt;&#10;       &lt;use xlink:href=&quot;#DejaVuSans-30&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;    &lt;/g&gt;&#10;    &lt;g id=&quot;xtick_2&quot;&gt;&#10;     &lt;g id=&quot;line2d_2&quot;&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#m9c9d0cf3b9&quot; x=&quot;145.867691&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_2&quot;&gt;&#10;      &lt;!-- 25 --&gt;&#10;      &lt;g transform=&quot;translate(139.505191 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-32&quot; d=&quot;M 1228 531 ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns


# Load the Iris dataset
iris = sns.load_dataset("iris")


def boxplot(orientation: str, fig_num: int):
    # Start a new figure
    plt.figure(num=fig_num)

    # Create box plot
    if orientation == "v":
        box_plot = sns.boxplot(
            x="species", y="petal_length", data=iris, orient=orientation
        )
        plt.xlabel("Species")
        plt.ylabel("Petal Length (cm)")
    else:
        box_plot = sns.boxplot(
            x="petal_length", y="species", data=iris, orient=orientation
        )
        plt.ylabel("Species")
        plt.xlabel("Petal Length (cm)")

    # Adding labels and title
    plt.title("Box Plot of Petal Length by Iris Species")

    return box_plot


# Create the vertical boxplot
vert = boxplot(orientation="v", fig_num=1)
# plt.show()
maidr.show(vert)
# Out:
# <iframe id="iframe_606aed70-fd73-4d5d-960c-dc96708241f9" srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;f804e59b-54df-4406-8c74-ddd0336bd6d9&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-09-30T05:11:01.882381&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.9.2, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;m98b34a7362&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#m98b34a7362&quot; x=&quot;236.16&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- Group 1 --&gt;&#10;      &lt;g transform=&quot;translate(216.170156 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-47&quot; d=&quot;M 3809 666  L 3809 1919  L 2778 1919  L 2778 2438  L 4434 2438  L 4434 434  Q 4069 175 3628 42  Q 3188 -91 2688 -91  Q 1594 -91 976 548  Q 359 1188 359 2328  Q 359 3472 976 4111  Q 1594 4750 2688 4750  Q 3144 4750 3555 4637  Q 3966 4525 4313 4306  L 4313 3634  Q 3963 3931 3569 4081  Q 3175 4231 2741 4231  Q 1884 4231 1454 3753  Q 1025 3275 1025 2328  Q 1025 1384 1454 906  Q 1884 428 2741 428  Q 3075 428 3337 486  Q 3600 544 3809 666  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-72&quot; d=&quot;M 2631 2963  Q 2534 3019 2420 3045  Q 2306 3072 2169 3072  Q 1681 3072 1420 2755  Q 1159 2438 1159 1844  L 1159 0  L 581 0  L 581 3500  L 1159 3500  L 1159 2956  Q 1341 3275 1631 3429  Q 1922 3584 2338 3584  Q 2397 3584 2469 3576  Q 2541 3569 2628 3553  L 2631 2963  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-6f&quot; d=&quot;M 1959 3097  Q 1497 3097 1228 2736  Q 959 2375 959 1747  Q 959 1119 1226 758  Q 1494 397 1959 397  Q 2419 397 2687 759  Q 2956 1122 2956 1747  Q 2956 2369 2687 2733  Q 2419 3097 1959 3097  z M 1959 3584  Q 27 ...

# %%
# Create the vertical boxplot
horz = boxplot(orientation="h", fig_num=2)
# plt.show()
maidr.show(horz)
# Out:
# <iframe id="iframe_de6faced-8a2a-44c7-ada8-0dd632d16d2d" srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;1e9ae090-789a-4944-8dde-2b72683687ab&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-09-30T05:11:05.680845&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.9.2, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;md64e660588&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#md64e660588&quot; x=&quot;92.844999&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- 0 --&gt;&#10;      &lt;g transform=&quot;translate(89.663749 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-30&quot; d=&quot;M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;       &lt;/defs&gt;&#10;       &lt;use xlink:href=&quot;#DejaVuSans-30&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;    &lt;/g&gt;&#10;    &lt;g id=&quot;xtick_2&quot;&gt;&#10;     &lt;g id=&quot;line2d_2&quot;&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#md64e660588&quot; x=&quot;142.185768&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_2&quot;&gt;&#10;      &lt;!-- 25 --&gt;&#10;      &lt;g transform=&quot;translate(135.823268 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-32&quot; d=&quot;M 1228 531 ...
