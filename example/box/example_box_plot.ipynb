# %%
import matplotlib.pyplot as plt
import maidr
import numpy as np

# Generating random data for three different groups
data_group1 = np.random.normal(100, 10, 200)
data_group2 = np.random.normal(90, 20, 200)
data_group3 = np.random.normal(80, 30, 200)

# Combine these different datasets into a list
data_to_plot = [data_group1, data_group2, data_group3]


# Create the boxplot
def boxplot(is_vert: bool):
    plt.figure()
    bp = plt.boxplot(data_to_plot, patch_artist=True, vert=is_vert)

    colors = ["lightblue", "lightgreen", "tan"]
    for patch, color in zip(bp["boxes"], colors):
        patch.set_facecolor(color)

    if is_vert:
        plt.xticks(ticks=[1, 2, 3], labels=["Group 1", "Group 2", "Group 3"])
        plt.title("Vertical Box Plot Example")
        plt.xlabel("Group")
        plt.ylabel("Values")
    else:
        plt.yticks(ticks=[1, 2, 3], labels=["Group 1", "Group 2", "Group 3"])
        plt.title("Horizontal Box Plot Example")
        plt.ylabel("Group")
        plt.xlabel("Values")

    return bp


# Create the vertical boxplot
vert = boxplot(is_vert=True)
# plt.show()
maidr.show(vert)
# Out:
# <iframe srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;aebb2026-d8d5-43b7-b3ca-a848ecbdcad2&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-08-19T15:05:42.736325&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.8.3, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;m166a0bf257&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#m166a0bf257&quot; x=&quot;117.12&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- Group 1 --&gt;&#10;      &lt;g transform=&quot;translate(97.130156 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-47&quot; d=&quot;M 3809 666  L 3809 1919  L 2778 1919  L 2778 2438  L 4434 2438  L 4434 434  Q 4069 175 3628 42  Q 3188 -91 2688 -91  Q 1594 -91 976 548  Q 359 1188 359 2328  Q 359 3472 976 4111  Q 1594 4750 2688 4750  Q 3144 4750 3555 4637  Q 3966 4525 4313 4306  L 4313 3634  Q 3963 3931 3569 4081  Q 3175 4231 2741 4231  Q 1884 4231 1454 3753  Q 1025 3275 1025 2328  Q 1025 1384 1454 906  Q 1884 428 2741 428  Q 3075 428 3337 486  Q 3600 544 3809 666  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-72&quot; d=&quot;M 2631 2963  Q 2534 3019 2420 3045  Q 2306 3072 2169 3072  Q 1681 3072 1420 2755  Q 1159 2438 1159 1844  L 1159 0  L 581 0  L 581 3500  L 1159 3500  L 1159 2956  Q 1341 3275 1631 3429  Q 1922 3584 2338 3584  Q 2397 3584 2469 3576  Q 2541 3569 2628 3553  L 2631 2963  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-6f&quot; d=&quot;M 1959 3097  Q 1497 3097 1228 2736  Q 959 2375 959 1747  Q 959 1119 1226 758  Q 1494 397 1959 397  Q 2419 397 2687 759  Q 2956 1122 2956 1747  Q 2956 2369 2687 2733  Q 2419 3097 1959 3097  z M 1959 3584  Q 2709 3584 3137 3096  Q 3566 2609 3566 1747  Q 3566 8 ...

# %%
# Create the vertical boxplot
horz = boxplot(is_vert=False)
# plt.show()
maidr.show(horz)
# Out:
# <iframe srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;47f6b4c3-8dcb-4517-98ee-ef7de82f0025&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-08-19T15:07:45.340175&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.8.3, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;m3f41d125d8&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#m3f41d125d8&quot; x=&quot;91.851743&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- 0 --&gt;&#10;      &lt;g transform=&quot;translate(88.670493 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-30&quot; d=&quot;M 2034 4250  Q 1547 4250 1301 3770  Q 1056 3291 1056 2328  Q 1056 1369 1301 889  Q 1547 409 2034 409  Q 2525 409 2770 889  Q 3016 1369 3016 2328  Q 3016 3291 2770 3770  Q 2525 4250 2034 4250  z M 2034 4750  Q 2819 4750 3233 4129  Q 3647 3509 3647 2328  Q 3647 1150 3233 529  Q 2819 -91 2034 -91  Q 1250 -91 836 529  Q 422 1150 422 2328  Q 422 3509 836 4129  Q 1250 4750 2034 4750  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;       &lt;/defs&gt;&#10;       &lt;use xlink:href=&quot;#DejaVuSans-30&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;    &lt;/g&gt;&#10;    &lt;g id=&quot;xtick_2&quot;&gt;&#10;     &lt;g id=&quot;line2d_2&quot;&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#m3f41d125d8&quot; x=&quot;139.404538&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_2&quot;&gt;&#10;      &lt;!-- 25 --&gt;&#10;      &lt;g transform=&quot;translate(133.042038 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-32&quot; d=&quot;M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 ...

# %%
import matplotlib.pyplot as plt
import maidr
import seaborn as sns


# Load the Iris dataset
iris = sns.load_dataset("iris")


def boxplot(orientation: str, fig_num: int):
    # Start a new figure
    plt.figure(num=fig_num)

    # Create box plot
    if orientation == "v":
        box_plot = sns.boxplot(
            x="species", y="petal_length", data=iris, orient=orientation
        )
        plt.xlabel("Species")
        plt.ylabel("Petal Length (cm)")
    else:
        box_plot = sns.boxplot(
            x="petal_length", y="species", data=iris, orient=orientation
        )
        plt.ylabel("Species")
        plt.xlabel("Petal Length (cm)")

    # Adding labels and title
    plt.title("Box Plot of Petal Length by Iris Species")

    return box_plot


# Create the vertical boxplot
vert = boxplot(orientation="v", fig_num=1)
# plt.show()
maidr.show(vert)
# Out:
# <iframe srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;8173aea8-4670-4177-b6db-d95eefdb0b40&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-08-19T15:08:40.466756&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.8.3, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;mf5c792c4b9&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#mf5c792c4b9&quot; x=&quot;117.12&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- setosa --&gt;&#10;      &lt;g transform=&quot;translate(100.750469 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-73&quot; d=&quot;M 2834 3397  L 2834 2853  Q 2591 2978 2328 3040  Q 2066 3103 1784 3103  Q 1356 3103 1142 2972  Q 928 2841 928 2578  Q 928 2378 1081 2264  Q 1234 2150 1697 2047  L 1894 2003  Q 2506 1872 2764 1633  Q 3022 1394 3022 966  Q 3022 478 2636 193  Q 2250 -91 1575 -91  Q 1294 -91 989 -36  Q 684 19 347 128  L 347 722  Q 666 556 975 473  Q 1284 391 1588 391  Q 1994 391 2212 530  Q 2431 669 2431 922  Q 2431 1156 2273 1281  Q 2116 1406 1581 1522  L 1381 1569  Q 847 1681 609 1914  Q 372 2147 372 2553  Q 372 3047 722 3315  Q 1072 3584 1716 3584  Q 2034 3584 2315 3537  Q 2597 3491 2834 3397  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &lt;path id=&quot;DejaVuSans-65&quot; d=&quot;M 3597 1894  L 3597 1613  L 953 1613  Q 991 1019 1311 708  Q 1631 397 2203 397  Q 2534 397 2845 478  Q 3156 559 3463 722  L 3463 178  Q 3153 47 2828 -22  Q 2503 -91 2169 -91  Q 1331 -91 842 396  Q 353 884 353 1716  Q 353 2575 817 3079  Q 1281 3584 2069 3584  Q 2775 3584 3186 3129  Q 3597 2675 3597 1894  z M 3022 2063  Q 3016 2534 2758 2815  Q 2500 3097 2075 3097  Q 1594 3097 1305 2825  Q 1016 2553 972 2059  L 3022 2063  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;        &l ...

# %%
# Create the vertical boxplot
horz = boxplot(orientation="h", fig_num=2)
# plt.show()
maidr.show(horz)
# Out:
# <iframe srcdoc="&lt;html&gt;&#10;  &lt;head&gt;&#10;    &lt;meta charset=&quot;UTF-8&quot;/&gt;&#10;    &lt;title&gt;MAIDR&lt;/title&gt;&#10;    &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr_style.min.css&quot;/&gt;&#10;    &lt;script type=&quot;text/javascript&quot; src=&quot;https://cdn.jsdelivr.net/npm/maidr/dist/maidr.min.js&quot;&gt;&lt;/script&gt;&#10;  &lt;/head&gt;&#10;  &lt;body&gt;&#10;    &lt;div&gt;&lt;svg xmlns:xlink=&quot;http://www.w3.org/1999/xlink&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;460.8pt&quot; height=&quot;345.6pt&quot; viewBox=&quot;0 0 460.8 345.6&quot; version=&quot;1.1&quot; id=&quot;fc4a7940-b1a4-4478-a13d-878a5646ebf8&quot;&gt;&#10; &lt;metadata&gt;&#10;  &lt;rdf:RDF xmlns:dc=&quot;http://purl.org/dc/elements/1.1/&quot; xmlns:cc=&quot;http://creativecommons.org/ns#&quot; xmlns:rdf=&quot;http://www.w3.org/1999/02/22-rdf-syntax-ns#&quot;&gt;&#10;   &lt;cc:Work&gt;&#10;    &lt;dc:type rdf:resource=&quot;http://purl.org/dc/dcmitype/StillImage&quot;/&gt;&#10;    &lt;dc:date&gt;2024-08-19T15:08:43.590399&lt;/dc:date&gt;&#10;    &lt;dc:format&gt;image/svg+xml&lt;/dc:format&gt;&#10;    &lt;dc:creator&gt;&#10;     &lt;cc:Agent&gt;&#10;      &lt;dc:title&gt;Matplotlib v3.8.3, https://matplotlib.org/&lt;/dc:title&gt;&#10;     &lt;/cc:Agent&gt;&#10;    &lt;/dc:creator&gt;&#10;   &lt;/cc:Work&gt;&#10;  &lt;/rdf:RDF&gt;&#10; &lt;/metadata&gt;&#10; &lt;defs&gt;&#10;  &lt;style type=&quot;text/css&quot;&gt;*{stroke-linejoin: round; stroke-linecap: butt}&lt;/style&gt;&#10; &lt;/defs&gt;&#10; &lt;g id=&quot;figure_1&quot;&gt;&#10;  &lt;g id=&quot;patch_1&quot;&gt;&#10;   &lt;path d=&quot;M 0 345.6  L 460.8 345.6  L 460.8 0  L 0 0  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;  &lt;/g&gt;&#10;  &lt;g id=&quot;axes_1&quot;&gt;&#10;   &lt;g id=&quot;patch_2&quot;&gt;&#10;    &lt;path d=&quot;M 57.6 307.584  L 414.72 307.584  L 414.72 41.472  L 57.6 41.472  z &quot; style=&quot;fill: #ffffff&quot;/&gt;&#10;   &lt;/g&gt;&#10;   &lt;g id=&quot;matplotlib.axis_1&quot;&gt;&#10;    &lt;g id=&quot;xtick_1&quot;&gt;&#10;     &lt;g id=&quot;line2d_1&quot;&gt;&#10;      &lt;defs&gt;&#10;       &lt;path id=&quot;mc961747536&quot; d=&quot;M 0 0  L 0 3.5  &quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/defs&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#mc961747536&quot; x=&quot;73.832727&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_1&quot;&gt;&#10;      &lt;!-- 1 --&gt;&#10;      &lt;g transform=&quot;translate(70.651477 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-31&quot; d=&quot;M 794 531  L 1825 531  L 1825 4091  L 703 3866  L 703 4441  L 1819 4666  L 2450 4666  L 2450 531  L 3481 531  L 3481 0  L 794 0  L 794 531  z &quot; transform=&quot;scale(0.015625)&quot;/&gt;&#10;       &lt;/defs&gt;&#10;       &lt;use xlink:href=&quot;#DejaVuSans-31&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;    &lt;/g&gt;&#10;    &lt;g id=&quot;xtick_2&quot;&gt;&#10;     &lt;g id=&quot;line2d_2&quot;&gt;&#10;      &lt;g&gt;&#10;       &lt;use xlink:href=&quot;#mc961747536&quot; x=&quot;128.858921&quot; y=&quot;307.584&quot; style=&quot;stroke: #000000; stroke-width: 0.8&quot;/&gt;&#10;      &lt;/g&gt;&#10;     &lt;/g&gt;&#10;     &lt;g id=&quot;text_2&quot;&gt;&#10;      &lt;!-- 2 --&gt;&#10;      &lt;g transform=&quot;translate(125.677671 322.182437) scale(0.1 -0.1)&quot;&gt;&#10;       &lt;defs&gt;&#10;        &lt;path id=&quot;DejaVuSans-32&quot; d=&quot;M 1228 531  L 3431 531  L 3431 0  L 469 0  L 469 531  Q 828 903 1448 1529  Q 2069 2156 2228 2338  Q 2531 2678 2651 2914  Q 2772 3150 2772 3378  Q 2772 3750 2511 3984  Q 2250 4219 1831 4219  Q 1534 4219 1204 4116  Q 875 4013 500 3803  L 500 4441  Q 881 4594 1212 4672  Q 1544 4750 1819 4750  Q 2544 475 ...
